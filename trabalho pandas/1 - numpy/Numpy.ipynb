# %%
# 1. leia o dataset usando pandas

import pandas as pd

salary_csv = pd.read_csv('Salary_Data.csv')
print(salary_csv)
# Out:
#     YearsExperience    Salary
# 0               1.1   39343.0
# 1               1.3   46205.0
# 2               1.5   37731.0
# 3               2.0   43525.0
# 4               2.2   39891.0
# 5               2.9   56642.0
# 6               3.0   60150.0
# 7               3.2   54445.0
# 8               3.2   64445.0
# 9               3.7   57189.0
# 10              3.9   63218.0
# 11              4.0   55794.0
# 12              4.0   56957.0
# 13              4.1   57081.0
# 14              4.5   61111.0
# 15              4.9   67938.0
# 16              5.1   66029.0
# 17              5.3   83088.0
# 18              5.9   81363.0
# 19              6.0   93940.0
# 20              6.8   91738.0
# 21              7.1   98273.0
# 22              7.9  101302.0
# 23              8.2  113812.0
# 24              8.7  109431.0
# 25              9.0  105582.0
# 26              9.5  116969.0
# 27              9.6  112635.0
# 28             10.3  122391.0
# 29             10.5  121872.0

# %%
# 2. Converta os dados relevantes em arrays NumPy (utilize o método .to_numpy())

salary = salary_csv.to_numpy()
print(salary)
# Out:
# [[1.10000e+00 3.93430e+04]
#  [1.30000e+00 4.62050e+04]
#  [1.50000e+00 3.77310e+04]
#  [2.00000e+00 4.35250e+04]
#  [2.20000e+00 3.98910e+04]
#  [2.90000e+00 5.66420e+04]
#  [3.00000e+00 6.01500e+04]
#  [3.20000e+00 5.44450e+04]
#  [3.20000e+00 6.44450e+04]
#  [3.70000e+00 5.71890e+04]
#  [3.90000e+00 6.32180e+04]
#  [4.00000e+00 5.57940e+04]
#  [4.00000e+00 5.69570e+04]
#  [4.10000e+00 5.70810e+04]
#  [4.50000e+00 6.11110e+04]
#  [4.90000e+00 6.79380e+04]
#  [5.10000e+00 6.60290e+04]
#  [5.30000e+00 8.30880e+04]
#  [5.90000e+00 8.13630e+04]
#  [6.00000e+00 9.39400e+04]
#  [6.80000e+00 9.17380e+04]
#  [7.10000e+00 9.82730e+04]
#  [7.90000e+00 1.01302e+05]
#  [8.20000e+00 1.13812e+05]
#  [8.70000e+00 1.09431e+05]
#  [9.00000e+00 1.05582e+05]
#  [9.50000e+00 1.16969e+05]
#  [9.60000e+00 1.12635e+05]
#  [1.03000e+01 1.22391e+05]
#  [1.05000e+01 1.21872e+05]]

# %%
# 3. Calcule a média de salário

import numpy as np

salary_sum = np.sum(salary[:, 1])
print(salary_sum)
print(salary.size)

media_salary = salary_sum/(salary.size/2)
print(media_salary)
# Out:
# 2280090.0
# 60
# 76003.0

# %%
# 4. Calcule a média de tempo de serviço.


time_service = np.sum(salary[:, 0])
print(time_service)
print(salary.size)

media_salary = time_service/(salary.size/2)
print(media_salary)
# Out:
# 159.4
# 60
# 5.3133333333333335

# %%
# 5. Encontre o sálario Médio dos funcionários com mais de 5 anos de serviço

mask = salary[:,0]  > 5
mask

salary_sum = np.sum(salary[mask][:, 1])
print(salary_sum)
print(salary.size)

media_salary = salary_sum/(salary[mask].size/2)
print(media_salary)
# Out:
# 1418425.0
# 60
# 101316.07142857143

# %%
# 6. Crie um gráfico de barras mostrando os salários referente ao tempo de serviço

import matplotlib.pyplot as plt
import seaborn as sns

# Separando as colunas
tempo_servico = salary[:, 0]  # Primeira coluna: tempo de serviço
salario = salary[:, 1]        # Segunda coluna: salário

# Criando o gráfico de barras com estilo melhorado
plt.figure(figsize=(12, 8))
plt.bar(tempo_servico, salario, width=0.1, color='skyblue', edgecolor='black', linewidth=1.2)

# Adicionando títulos e rótulos
plt.title('Salário por Tempo de Serviço', fontsize=16, fontweight='bold')
plt.xlabel('Tempo de Serviço (anos)', fontsize=14)
plt.ylabel('Salário (R$)', fontsize=14)

# Estilizando os ticks e a grade
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Melhorando a margem do gráfico
plt.tight_layout()

# Mostrando o gráfico
plt.show()

# %%
# 7. Considere um aumento de 10% para o salário de cada funcionário e apresente o resultado do aumento
print("Salario:")
print(salary[:, 1])
print("\nSalario com o aumento de 10%:")
print(salary[:, 1] * 1.1)
# Out:
# Salario:
# [ 39343.  46205.  37731.  43525.  39891.  56642.  60150.  54445.  64445.
#   57189.  63218.  55794.  56957.  57081.  61111.  67938.  66029.  83088.
#   81363.  93940.  91738.  98273. 101302. 113812. 109431. 105582. 116969.
#  112635. 122391. 121872.]
#
# Salario com o aumento de 10%:
# [ 43277.3  50825.5  41504.1  47877.5  43880.1  62306.2  66165.   59889.5
#   70889.5  62907.9  69539.8  61373.4  62652.7  62789.1  67222.1  74731.8
#   72631.9  91396.8  89499.3 103334.  100911.8 108100.3 111432.2 125193.2
#  120374.1 116140.2 128665.9 123898.5 134630.1 134059.2]
